# %%
import serial
import threading
from jetbot import Robot
from time import sleep

# %%
port = "/dev/ttyACM0"
rate = 57600
s1 = serial.Serial(port, rate)
s1.reset_input_buffer()

# %%
def read_serial():
    count = 0
    while True:
        line = s1.readline().decode('utf-8').split()
#         print("read_serial count:{}  output:{}".format(count, line))
        return line

# %%
def print_line():
    count = 0
    while True:
        count += 1
#         print("before call")
        print("print_line count:{}  output:{}".format(count, read_serial()))
#         print("after call")
#         sleep(1)
#         print(read_serial())

# %%
def main():
#     t1 = threading.Thread(name="ZZZ", target=read_serial)
#     t1.start()
    t2 = threading.Thread(name="XXX", target=print_line)
    t2.start()
    robot = Robot()
    robot.forward(-0.3)
    sleep(1)
    robot.stop()
#     robot.stop()
#     print("Backwards...")
#     sleep(5)
#     robot.backward(0.5)
#     sleep(0.3)
#     robot.stop()
# #     print_line()
#     print("**************")

# %%
main()
# Out:
# Exception in thread XXX:
# Traceback (most recent call last):
#   File "/home/jetbot/.local/lib/python3.6/site-packages/serial/serialposix.py", line 501, in read
#     'device reports readiness to read but returned no data '
# serial.serialutil.SerialException: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-467fc7cb4faa>", line 6, in print_line
#     print("print_line count:{}  output:{}".format(count, read_serial()))
#   File "<ipython-input-3-b3bdfbb6b121>", line 4, in read_serial
#     line = s1.readline().decode('utf-8').split()
#   File "/home/jetbot/.local/lib/python3.6/site-packages/serial/serialposix.py", line 509, in read
#     raise SerialException('read failed: {}'.format(e))
# serial.serialutil.SerialException: read failed: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# print_line count:736  output:['L', 'wheel:', '4']
# print_line count:737  output:['R', 'wheel:', '-187']
# print_line count:738  output:['L', 'wheel:', '3']
# print_line count:739  output:['R', 'wheel:', '-188']
# print_line count:740  output:['L', 'wheel:', '2']
# print_line count:741  output:['R', 'wheel:', '-189']
# print_line count:742  output:['L', 'wheel:', '1']
# print_line count:743  output:['R', 'wheel:', '-190']
# print_line count:744  output:['L', 'wheel:', '0']
# print_line count:745  output:['L', 'wheel:', '-1']
# print_line count:746  output:['R', 'wheel:', '-191']
# print_line count:747  output:['L', 'wheel:', '-2']
# print_line count:748  output:['R', 'wheel:', '-192']
# print_line count:749  output:['L', 'wheel:', '-3']
# print_line count:750  output:['R', 'wheel:', '-193']
# print_line count:751  output:['L', 'wheel:', '-4']
# print_line count:752  output:['R', 'wheel:', '-194']
# print_line count:753  output:['L', 'wheel:', '-5']
# print_line count:754  output:['R', 'wheel:', '-195']
# print_line count:755  output:['L', 'wheel:', '-6']
# print_line count:756  output:['R', 'wheel:', '-196']
# print_line count:757  output:['L', 'wheel:', '-7']
# print_line count:758  output:['R', 'wheel:', '-197']
# print_line count:759  output:['R', 'wheel:', '-198']
# print_line count:760  output:['L', 'wheel:', '-6']
# print_line count:761  output:['R', 'wheel:', '-197']
# print_line count:762  output:['R', 'wheel:', '-196']
# print_line count:763  output:['R', 'wheel:', '-195']
# print_line count:764  output:['R', 'wheel:', '-194']
# print_line count:765  output:['R', 'wheel:', '-193']
# print_line count:766  output:['R', 'wheel:', '-192']
# print_line count:767  output:['R', 'wheel:', '-193']
# print_line count:768  output:['R', 'wheel:', '-194']
# print_line count:769  output:['R', 'wheel:', '-195']
# print_line count:770  output:['R', 'wheel:', '-194']
# print_line count:771  output:['R', 'wheel:', '-193']
# print_line count:772  output:['R', 'wheel:', '-194']
# print_line count:773  output:['R', 'wheel:', '-195']
# print_line count:774  output:['R', 'wheel:', '-194']
# print_line count:775  output:['R', 'wheel:', '-195']
# print_line count:776  output:['R', 'wheel:', '-196']
# print_line count:777  output:['R', 'wheel:', '-195']
# print_line count:778  output:['R', 'wheel:', '-196']
# print_line count:779  output:['R', 'wheel:', '-197']
# print_line count:780  output:['R', 'wheel:', '-196']
# print_line count:781  output:['R', 'wheel:', '-197']
# print_line count:782  output:['R', 'wheel:', '-196']
# print_line count:783  output:['R', 'wheel:', '-197']
# print_line count:784  output:['R', 'wheel:', '-198']
# print_line count:785  output:['R', 'wheel:', '-199']
# print_line count:786  output:['R', 'wheel:', '-198']
# print_line count:787  output:['R', 'wheel:', '-199']
# print_line count:788  output:['R', 'wheel:', '-198']
# print_line count:789  output:['R', 'wheel:', '-199']
# print_line count:790  output:['R', 'wheel:', '-198']
# print_line count:791  output:['R', 'wheel:', '-199']
# print_line count:792  output:['R', 'wheel:', '-200']
# print_line count:793  output:['R', 'wheel:', '-199']
# print_line count:794  output:['R', 'wheel:', '-200']
# print_line count:795  output:['R', 'wheel:', '-201']
# print_line count:796  output:['R', 'wheel:', '-200']
# print_line count:797  output:['R', 'wheel:', '-199']
# print_line count:798  output:['R', 'wheel:', '-200']
# print_line count:799  output:['R', 'wheel:', '-199']
# print_line count:800  output:['R', 'wheel:', '-198']
# print_line count:801  output:['R', 'wheel:', '-199']
# print_line count:802  output:['R', 'wheel:', '-200']
# print_line count:803  output:['R', 'wheel:', '-201']
# print_line count:804  output:['R', 'wheel:', '-200']
# print_line count:805  output:['R', 'wheel:', '-199']
# print_line count:806  output:['R', 'wheel:', '-200']
# print_line count:807  output:['R', 'wheel:', '-201']
# print_line count:808  output:['R', 'wheel:', '-200']
# print_line count:809  output:['R', 'wheel:', '-199']
# print_line count:810  output:['R', 'wheel:', '-200']
# print_line count:811  output:['R', 'wheel:', '-201']
# print_line count:812  output:['R', 'wheel:', '-202']
# print_line count:813  output:['R', 'wheel:', '-203']
# print_line count:814  output:['R', 'wheel:', '-204']
# print_line count:815  output:['R', 'wheel:', '-205']
# print_line count:816  output:['R', 'wheel:', '-204']
# print_line count:817  output:['R', 'wheel:', '-203']
# print_line count:818  output:['R', 'wheel:', '-202']
# print_line count:819  output:['R', 'wheel:', '-201']
# print_line count:820  output:['R', 'wheel:', '-200']
# print_line count:821  output:['R', 'wheel:', '-199']
# print_line count:822  output:['R', 'wheel:', '-198']
# print_line count:823  output:['R', 'wheel:', '-197']
# print_line count:824  output:['R', 'wheel:', '-196']
# print_line count:825  output:['R', 'wheel:', '-195']
# print_line count:826  output:['R', 'wheel:', '-194']
# print_line count:827  output:['R', 'wheel:', '-193']
# print_line count:828  output:['R', 'wheel:', '-192']
# print_line count:829  output:['R', 'wheel:', '-191']
# print_line count:830  output:['R', 'wheel:', '-190']
# print_line count:831  output:['R', 'wheel:', '-189']
# print_line count:832  output:['R', 'wheel:', '-188']
# print_line count:833  output:['R', 'wheel:', '-189']
# print_line count:834  output:['R', 'wheel:', '-190']
# print_line count:835  output:['R', 'wheel:', '-191']
# print_line count:836  output:['R', 'wheel:', '-192']
# print_line count:837  output:['R', 'wheel:', '-193']
# print_line count:838  output:['R', 'wheel:', '-194']
# print_line count:839  output:['R', 'wheel:', '-195']
# print_line count:840  output:['R', 'wheel:', '-196']
# print_line count:841  output:['R', 'wheel:', '-195']
# print_line count:842  output:['R', 'wheel:', '-194']
# print_line count:843  output:['R', 'wheel:', '-195']
# print_line count:844  output:['R', 'wheel:', '-196']
# print_line count:845  output:['R', 'wheel:', '-197']
# print_line count:846  output:['R', 'wheel:', '-198']
# print_line count:847  output:['R', 'wheel:', '-197']
# print_line count:848  output:['R', 'wheel:', '-196']
# print_line count:849  output:['R', 'wheel:', '-197']
# print_line count:850  output:['R', 'wheel:', '-198']
# print_line count:851  output:['R', 'wheel:', '-199']
# print_line count:852  output:['R', 'wheel:', '-200']
# print_line count:853  output:['R', 'wheel:', '-199']
# print_line count:854  output:['R', 'wheel:', '-198']
# print_line count:855  output:['R', 'wheel:', '-199']
# print_line count:856  output:['R', 'wheel:', '-200']
# print_line count:857  output:['R', 'wheel:', '-201']
# print_line count:858  output:['R', 'wheel:', '-200']
# print_line count:859  output:['R', 'wheel:', '-201']
# print_line count:860  output:['R', 'wheel:', '-202']
# print_line count:861  output:['R', 'wheel:', '-203']
# print_line count:862  output:['R', 'wheel:', '-202']
# print_line count:863  output:['R', 'wheel:', '-201']
# print_line count:864  output:['R', 'wheel:', '-202']
# print_line count:865  output:['R', 'wheel:', '-203']
# print_line count:866  output:['R', 'wheel:', '-202']
# print_line count:867  output:['R', 'wheel:', '-203']
# print_line count:868  output:['R', 'wheel:', '-204']
# print_line count:869  output:['R', 'wheel:', '-205']
# print_line count:870  output:['R', 'wheel:', '-204']
# print_line count:871  output:['R', 'wheel:', '-205']
# print_line count:872  output:['R', 'wheel:', '-206']
# print_line count:873  output:['R', 'wheel:', '-205']
# print_line count:874  output:['R', 'wheel:', '-206']
# print_line count:875  output:['R', 'wheel:', '-207']
# print_line count:876  output:['R', 'wheel:', '-208']
# print_line count:877  output:['R', 'wheel:', '-207']
# print_line count:878  output:['R', 'wheel:', '-208']
# print_line count:879  output:['R', 'wheel:', '-209']
# print_line count:880  output:['R', 'wheel:', '-208']
# print_line count:881  output:['R', 'wheel:', '-209']
# print_line count:882  output:['R', 'wheel:', '-210']
# print_line count:883  output:['R', 'wheel:', '-209']
# print_line count:884  output:['R', 'wheel:', '-210']
# print_line count:885  output:['R', 'wheel:', '-211']
# print_line count:886  output:['R', 'wheel:', '-210']
# print_line count:887  output:['R', 'wheel:', '-211']
# print_line count:888  output:['R', 'wheel:', '-212']
# print_line count:889  output:['R', 'wheel:', '-211']
# print_line count:890  output:['R', 'wheel:', '-212']
# print_line count:891  output:['R', 'wheel:', '-213']
# print_line count:892  output:['R', 'wheel:', '-212']
# print_line count:893  output:['R', 'wheel:', '-213']
# print_line count:894  output:['R', 'wheel:', '-214']
# print_line count:895  output:['R', 'wheel:', '-213']
# print_line count:896  output:['R', 'wheel:', '-214']
# print_line count:897  output:['R', 'wheel:', '-215']
# print_line count:898  output:['R', 'wheel:', '-214']
# print_line count:899  output:['R', 'wheel:', '-215']
# print_line count:900  output:['R', 'wheel:', '-216']
# print_line count:901  output:['R', 'wheel:', '-215']
# print_line count:902  output:['R', 'wheel:', '-216']
# print_line count:903  output:['R', 'wheel:', '-215']
# print_line count:904  output:['R', 'wheel:', '-214']
# print_line count:905  output:['R', 'wheel:', '-215']
# print_line count:906  output:['R', 'wheel:', '-216']
# print_line count:907  output:['R', 'wheel:', '-215']
# print_line count:908  output:['R', 'wheel:', '-216']
# print_line count:909  output:['R', 'wheel:', '-215']
# print_line count:910  output:['R', 'wheel:', '-216']
# print_line count:911  output:['R', 'wheel:', '-217']
# print_line count:912  output:['R', 'wheel:', '-216']
# print_line count:913  output:['R', 'wheel:', '-217']
# print_line count:914  output:['R', 'wheel:', '-218']
# print_line count:915  output:['R', 'wheel:', '-217']
# print_line count:916  output:['R', 'wheel:', '-218']
# print_line count:917  output:['R', 'wheel:', '-219']
# print_line count:918  output:['R', 'wheel:', '-218']
# print_line count:919  output:['R', 'wheel:', '-219']
# print_line count:920  output:['R', 'wheel:', '-218']
# print_line count:921  output:['R', 'wheel:', '-219']
# print_line count:922  output:['R', 'wheel:', '-220']
# print_line count:923  output:['R', 'wheel:', '-219']
# print_line count:924  output:['R', 'wheel:', '-220']
# print_line count:925  output:['R', 'wheel:', '-221']
# print_line count:926  output:['R', 'wheel:', '-220']
# print_line count:927  output:['R', 'wheel:', '-221']
# print_line count:928  output:['R', 'wheel:', '-222']
# print_line count:929  output:['R', 'wheel:', '-221']
# print_line count:930  output:['R', 'wheel:', '-222']
# print_line count:931  output:['R', 'wheel:', '-221']
# print_line count:932  output:['R', 'wheel:', '-222']
# print_line count:933  output:['R', 'wheel:', '-223']
# print_line count:934  output:['R', 'wheel:', '-222']
# print_line count:935  output:['R', 'wheel:', '-223']
# print_line count:936  output:['R', 'wheel:', '-222']
# print_line count:937  output:['R', 'wheel:', '-223']
# print_line count:938  output:['R', 'wheel:', '-224']
# print_line count:939  output:['R', 'wheel:', '-223']
# print_line count:940  output:['R', 'wheel:', '-224']
# print_line count:941  output:['R', 'wheel:', '-223']
# print_line count:942  output:['R', 'wheel:', '-224']
# print_line count:943  output:['R', 'wheel:', '-225']
# print_line count:944  output:['R', 'wheel:', '-224']
# print_line count:945  output:['R', 'wheel:', '-225']
# print_line count:946  output:['R', 'wheel:', '-226']
# print_line count:947  output:['R', 'wheel:', '-227']
# print_line count:948  output:['R', 'wheel:', '-228']
# print_line count:949  output:['R', 'wheel:', '-227']
# print_line count:950  output:['R', 'wheel:', '-228']
# print_line count:951  output:['R', 'wheel:', '-229']
# print_line count:952  output:['R', 'wheel:', '-228']
# print_line count:953  output:['R', 'wheel:', '-229']
# print_line count:954  output:['R', 'wheel:', '-228']
# print_line count:955  output:['R', 'wheel:', '-229']
# print_line count:956  output:['R', 'wheel:', '-228']
# print_line count:957  output:['R', 'wheel:', '-227']
# print_line count:958  output:['R', 'wheel:', '-228']
# print_line count:959  output:['R', 'wheel:', '-227']
# print_line count:960  output:['R', 'wheel:', '-228']
# print_line count:961  output:['R', 'wheel:', '-227']
# print_line count:962  output:['R', 'wheel:', '-228']
# print_line count:963  output:['R', 'wheel:', '-229']
# print_line count:964  output:['R', 'wheel:', '-228']
# print_line count:965  output:['R', 'wheel:', '-229']
# print_line count:966  output:['R', 'wheel:', '-228']
# print_line count:967  output:['R', 'wheel:', '-229']
# print_line count:968  output:['R', 'wheel:', '-230']
# print_line count:969  output:['R', 'wheel:', '-229']
# print_line count:970  output:['R', 'wheel:', '-230']
# print_line count:971  output:['R', 'wheel:', '-229']
# print_line count:972  output:['R', 'wheel:', '-230']
# print_line count:973  output:['R', 'wheel:', '-229']
# print_line count:974  output:['R', 'wheel:', '-230']
# print_line count:975  output:['R', 'wheel:', '-229']
# print_line count:976  output:['R', 'wheel:', '-230']
# print_line count:977  output:['R', 'wheel:', '-231']
# print_line count:978  output:['R', 'wheel:', '-230']
# print_line count:979  output:['R', 'wheel:', '-231']
# print_line count:980  output:['R', 'wheel:', '-230']
# print_line count:981  output:['R', 'wheel:', '-231']
# print_line count:982  output:['R', 'wheel:', '-232']
# print_line count:983  output:['R', 'wheel:', '-231']
# print_line count:984  output:['R', 'wheel:', '-232']
# print_line count:985  output:['R', 'wheel:', '-231']
# print_line count:986  output:['R', 'wheel:', '-232']
# print_line count:987  output:['R', 'wheel:', '-233']
# print_line count:988  output:['R', 'wheel:', '-232']
# print_line count:989  output:['R', 'wheel:', '-233']
# print_line count:990  output:['R', 'wheel:', '-232']
# print_line count:991  output:['R', 'wheel:', '-233']
# print_line count:992  output:['R', 'wheel:', '-234']
# print_line count:993  output:['R', 'wheel:', '-235']
# print_line count:994  output:['R', 'wheel:', '-236']
# print_line count:995  output:['R', 'wheel:', '-237']
# print_line count:996  output:['R', 'wheel:', '-238']
# print_line count:997  output:['R', 'wheel:', '-237']
# print_line count:998  output:['R', 'wheel:', '-238']
# print_line count:999  output:['R', 'wheel:', '-239']
# print_line count:1000  output:['R', 'wheel:', '-240']
# print_line count:1001  output:['R', 'wheel:', '-241']
# print_line count:1002  output:['R', 'wheel:', '-240']
# print_line count:1003  output:['R', 'wheel:', '-241']
# print_line count:1004  output:['R', 'wheel:', '-240']
# print_line count:1005  output:['R', 'wheel:', '-241']
# print_line count:1006  output:['R', 'wheel:', '-242']
# print_line count:1007  output:['R', 'wheel:', '-241']
# print_line count:1008  output:['R', 'wheel:', '-242']
# print_line count:1009  output:['R', 'wheel:', '-241']
# print_line count:1010  output:['R', 'wheel:', '-242']
# print_line count:1011  output:['R', 'wheel:', '-243']
# print_line count:1012  output:['R', 'wheel:', '-242']
# print_line count:1013  output:['R', 'wheel:', '-243']
# print_line count:1014  output:['R', 'wheel:', '-242']
# print_line count:1015  output:['R', 'wheel:', '-243']
# print_line count:1016  output:['R', 'wheel:', '-242']
# print_line count:1017  output:['R', 'wheel:', '-243']
# print_line count:1018  output:['R', 'wheel:', '-244']
# print_line count:1019  output:['R', 'wheel:', '-245']
# print_line count:1020  output:['R', 'wheel:', '-246']
# print_line count:1021  output:['R', 'wheel:', '-245']
# print_line count:1022  output:['R', 'wheel:', '-246']
# print_line count:1023  output:['R', 'wheel:', '-245']
# print_line count:1024  output:['R', 'wheel:', '-246']
# print_line count:1025  output:['R', 'wheel:', '-247']
# print_line count:1026  output:['R', 'wheel:', '-246']
# print_line count:1027  output:['R', 'wheel:', '-247']
# print_line count:1028  output:['R', 'wheel:', '-246']
# print_line count:1029  output:['R', 'wheel:', '-247']
# print_line count:1030  output:['R', 'wheel:', '-248']
# print_line count:1031  output:['R', 'wheel:', '-247']
# print_line count:1032  output:['R', 'wheel:', '-248']
# print_line count:1033  output:['R', 'wheel:', '-247']
# print_line count:1034  output:['R', 'wheel:', '-248']
# print_line count:1035  output:['R', 'wheel:', '-247']
# print_line count:1036  output:['R', 'wheel:', '-248']
# print_line count:1037  output:['R', 'wheel:', '-249']
# print_line count:1038  output:['R', 'wheel:', '-250']
# print_line count:1039  output:['R', 'wheel:', '-251']
# print_line count:1040  output:['R', 'wheel:', '-250']
# print_line count:1041  output:['R', 'wheel:', '-251']
# print_line count:1042  output:['R', 'wheel:', '-250']
# print_line count:1043  output:['R', 'wheel:', '-251']
# print_line count:1044  output:['R', 'wheel:', '-252']
# print_line count:1045  output:['R', 'wheel:', '-251']
# print_line count:1046  output:['R', 'wheel:', '-252']
# print_line count:1047  output:['R', 'wheel:', '-251']
# print_line count:1048  output:['R', 'wheel:', '-252']
# print_line count:1049  output:['R', 'wheel:', '-253']
# print_line count:1050  output:['R', 'wheel:', '-252']
# print_line count:1051  output:['R', 'wheel:', '-253']
# print_line count:1052  output:['R', 'wheel:', '-252']
# print_line count:1053  output:['R', 'wheel:', '-253']
# print_line count:1054  output:['R', 'wheel:', '-254']
# print_line count:1055  output:['R', 'wheel:', '-253']
# print_line count:1056  output:['R', 'wheel:', '-254']
# print_line count:1057  output:['R', 'wheel:', '-253']
# print_line count:1058  output:['R', 'wheel:', '-254']
# print_line count:1059  output:['R', 'wheel:', '-255']
# print_line count:1060  output:['R', 'wheel:', '-254']
# print_line count:1061  output:['R', 'wheel:', '-255']
# print_line count:1062  output:['R', 'wheel:', '-254']
# print_line count:1063  output:['R', 'wheel:', '-255']
# print_line count:1064  output:['R', 'wheel:', '-256']
# print_line count:1065  output:['R', 'wheel:', '-255']
# print_line count:1066  output:['R', 'wheel:', '-256']
# print_line count:1067  output:['R', 'wheel:', '-255']
# print_line count:1068  output:['R', 'wheel:', '-256']
# print_line count:1069  output:['R', 'wheel:', '-257']
# print_line count:1070  output:['R', 'wheel:', '-256']
# print_line count:1071  output:['R', 'wheel:', '-257']
# print_line count:1072  output:['R', 'wheel:', '-258']
# print_line count:1073  output:['R', 'wheel:', '-259']
# print_line count:1074  output:['R', 'wheel:', '-260']
# print_line count:1075  output:['R', 'wheel:', '-259']
# print_line count:1076  output:['R', 'wheel:', '-260']
# print_line count:1077  output:['R', 'wheel:', '-261']
# print_line count:1078  output:['R', 'wheel:', '-262']
# print_line count:1079  output:['R', 'wheel:', '-263']
# print_line count:1080  output:['R', 'wheel:', '-262']
# print_line count:1081  output:['R', 'wheel:', '-263']
# print_line count:1082  output:['R', 'wheel:', '-262']
# print_line count:1083  output:['R', 'wheel:', '-263']
# print_line count:1084  output:['R', 'wheel:', '-264']
# print_line count:1085  output:['R', 'wheel:', '-263']
# print_line count:1086  output:['R', 'wheel:', '-264']
# print_line count:1087  output:['R', 'wheel:', '-263']
# print_line count:1088  output:['R', 'wheel:', '-264']
# print_line count:1089  output:['R', 'wheel:', '-265']
# print_line count:1090  output:['R', 'wheel:', '-264']
# print_line count:1091  output:['R', 'wheel:', '-265']
# print_line count:1092  output:['R', 'wheel:', '-266']
# print_line count:1093  output:['R', 'wheel:', '-267']
# print_line count:1094  output:['R', 'wheel:', '-268']
# print_line count:1095  output:['R', 'wheel:', '-267']
# print_line count:1096  output:['R', 'wheel:', '-268']
# print_line count:1097  output:['R', 'wheel:', '-267']
# print_line count:1098  output:['R', 'wheel:', '-268']
# print_line count:1099  output:['R', 'wheel:', '-269']
# print_line count:1100  output:['R', 'wheel:', '-268']
# print_line count:1101  output:['R', 'wheel:', '-269']
# print_line count:1102  output:['R', 'wheel:', '-268']
# print_line count:1103  output:['R', 'wheel:', '-269']
# print_line count:1104  output:['R', 'wheel:', '-270']
# print_line count:1105  output:['R', 'wheel:', '-269']
# print_line count:1106  output:['R', 'wheel:', '-270']
# print_line count:1107  output:['R', 'wheel:', '-269']
# print_line count:1108  output:['R', 'wheel:', '-270']
# print_line count:1109  output:['R', 'wheel:', '-271']
# print_line count:1110  output:['R', 'wheel:', '-270']
# print_line count:1111  output:['R', 'wheel:', '-271']
# print_line count:1112  output:['R', 'wheel:', '-270']
# print_line count:1113  output:['R', 'wheel:', '-271']
# print_line count:1114  output:['R', 'wheel:', '-272']
# print_line count:1115  output:['R', 'wheel:', '-271']
# print_line count:1116  output:['R', 'wheel:', '-272']
# print_line count:1117  output:['R', 'wheel:', '-271']
# print_line count:1118  output:['R', 'wheel:', '-272']
# print_line count:1119  output:['R', 'wheel:', '-271']
# print_line count:1120  output:['R', 'wheel:', '-272']
# print_line count:1121  output:['R', 'wheel:', '-271']
# print_line count:1122  output:['R', 'wheel:', '-272']
# print_line count:1123  output:['R', 'wheel:', '-273']
# print_line count:1124  output:['R', 'wheel:', '-272']
# print_line count:1125  output:['R', 'wheel:', '-273']
# print_line count:1126  output:['R', 'wheel:', '-272']
# print_line count:1127  output:['R', 'wheel:', '-273']
# print_line count:1128  output:['R', 'wheel:', '-274']
# print_line count:1129  output:['R', 'wheel:', '-273']
# print_line count:1130  output:['R', 'wheel:', '-274']
# print_line count:1131  output:['R', 'wheel:', '-273']
# print_line count:1132  output:['R', 'wheel:', '-274']
# print_line count:1133  output:['R', 'wheel:', '-273']
# print_line count:1134  output:['R', 'wheel:', '-274']
# print_line count:1135  output:['R', 'wheel:', '-273']
# print_line count:1136  output:['R', 'wheel:', '-272']
# print_line count:1137  output:['R', 'wheel:', '-273']
# print_line count:1138  output:['R', 'wheel:', '-274']
# print_line count:1139  output:['R', 'wheel:', '-275']
# print_line count:1140  output:['R', 'wheel:', '-274']
# print_line count:1141  output:['R', 'wheel:', '-273']
# print_line count:1142  output:['R', 'wheel:', '-272']
# print_line count:1143  output:['R', 'wheel:', '-271']
# print_line count:1144  output:['R', 'wheel:', '-272']
# print_line count:1145  output:['R', 'wheel:', '-273']
# print_line count:1146  output:['R', 'wheel:', '-274']
# print_line count:1147  output:['R', 'wheel:', '-275']
# print_line count:1148  output:['R', 'wheel:', '-274']
# print_line count:1149  output:['R', 'wheel:', '-275']
# print_line count:1150  output:['R', 'wheel:', '-274']
# print_line count:1151  output:['R', 'wheel:', '-275']
# print_line count:1152  output:['R', 'wheel:', '-274']
# print_line count:1153  output:['R', 'wheel:', '-275']
# print_line count:1154  output:['R', 'wheel:', '-274']
# print_line count:1155  output:['R', 'wheel:', '-275']
# print_line count:1156  output:['R', 'wheel:', '-276']
# print_line count:1157  output:['R', 'wheel:', '-275']
# print_line count:1158  output:['R', 'wheel:', '-276']
# print_line count:1159  output:['R', 'wheel:', '-277']
# print_line count:1160  output:['R', 'wheel:', '-278']
# print_line count:1161  output:['R', 'wheel:', '-279']
# print_line count:1162  output:['R', 'wheel:', '-280']
# print_line count:1163  output:['R', 'wheel:', '-279']
# print_line count:1164  output:['R', 'wheel:', '-280']
# print_line count:1165  output:['R', 'wheel:', '-279']
# print_line count:1166  output:['R', 'wheel:', '-280']
# print_line count:1167  output:['R', 'wheel:', '-281']
# print_line count:1168  output:['R', 'wheel:', '-282']
# print_line count:1169  output:['R', 'wheel:', '-283']
# print_line count:1170  output:['L', 'wheel:', '-5']
# print_line count:1171  output:['R', 'wheel:', '-284']
# print_line count:1172  output:['R', 'wheel:', '-285']
# print_line count:1173  output:['R', 'wheel:', '-286']
# print_line count:1174  output:['L', 'wheel:', '-4']
# print_line count:1175  output:['R', 'wheel:', '-287']
# print_line count:1176  output:['R', 'wheel:', '-288']
# print_line count:1177  output:['L', 'wheel:', '-5']
# print_line count:1178  output:['R', 'wheel:', '-289']
# print_line count:1179  output:['R', 'wheel:', '-290']
# print_line count:1180  output:['R', 'wheel:', '-291']
# print_line count:1181  output:['R', 'wheel:', '-292']
# print_line count:1182  output:['R', 'wheel:', '-293']
# print_line count:1183  output:['R', 'wheel:', '-294']
# print_line count:1184  output:['R', 'wheel:', '-295']
# print_line count:1185  output:['R', 'wheel:', '-296']
